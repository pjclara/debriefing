# %%
import pyodbc

conn = pyodbc.connect(
    r"Driver={Microsoft Access Driver (*.mdb, *.accdb)};"
    r"DBQ=db.accdb;"
)

cursor = conn.cursor()
cursor.execute("SELECT * FROM NomeDaTabela")

for row in cursor.fetchall():
    print(row)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pyodbc
# ----> 3 conn = pyodbc.connect(
#       4     r"Driver={Microsoft Access Driver (*.mdb, *.accdb)};"
#       5     r"DBQ=db.accdb;"
#       6 )
#       8 cursor = conn.cursor()
#       9 cursor.execute("SELECT * FROM NomeDaTabela")
#
# Error: ('HY000', '[HY000] [Microsoft][Controlador Microsoft Access de ODBC] Não é um nome de ficheiro válido. (-1044) (SQLDriverConnect); [HY000] [Microsoft][Controlador Microsoft Access de ODBC] Não é um nome de ficheiro válido. (-1044)')
